# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
#Scatter Plot
sns.scatterplot(data=iris, x='sepal_length', y='sepal_Width', hue='species')
#Countplot for two categorical variable
sns.countplot(x='sex', hue="smoker", data=tips)
#Countplot on single categorical variable
sns.countplot(x='sex', data=tips)
#Categorical Plot
sns.catplot(data=tips, x='day', y='total_bill', kind='swarm', hue='sex')
#Pair Plot
sns.pairplot(iris, hue='species')
#Violin Plot
sns.violinplot(data=tips, x='day', y='total_bill', hue='sex', split=True)
#Heatmap
corr = tips.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
#boxplot
sns.boxplot(data=tips,x='day',y='total_bille', hue='sex', notch=True,palette="Set2")
#Histogram And KDE plot
sns.histplot(data=tips, x='total_bill', kde=True)
#Line Plot
sns.lineplot(data=flights, x='year', y='passengers')

# %%
x=np.array([1,2,3,4,5])
y=np.array([5,2,3,1,4])
plt.figure(figsize=(4,4))
plt.title("DATA",fontsize=30)
plt.plot(x,y,color='red',marker='.',linestyle="--")
plt.scatter(x,y,color='blue',marker='o')
plt.barh(categories,values,color='orange')
plt.hist(data,bins=30)
plt.xlabel("X-AXIS",fontsize=20)
plt.ylabel("Y-AXIS",fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylim(0,10)
plt.xlim(0,10)
plt.show()
plt.subplot(2,2,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 x=np.array([1,2,3,4,5])
#       2 y=np.array([5,2,3,1,4])
# ----> 3 plt.figure(figsize=(4,4))
#       4 plt.title("DATA",fontsize=30)
#       5 plt.plot(x,y,color='red',marker='.',linestyle="--")
#
# TypeError: 'module' object is not callable
