# %%
import pandas as pd
import numpy as np

# %%
data = [10,20,30,40,50]
series = pd.Series(data, index=['a','b','c','d','e'])
print("Pandas Series:- ")
print(series)
print(type(series))
# Out:
# Pandas Series:-
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
data = [10,20,30,40,50]
series = pd.Series(data)
print("Pandas Series:- ")
print(series)
print(type(series))
# Out:
# Pandas Series:-
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
#Creating a Pandas DataFrame
data = {
        'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25,30,35],
        'City': ['New York', 'London', 'Berlin']        
}
df = pd.DataFrame(data)
print("\nPandas DataFrame: ")
print(df)
display(data)
print(type(data), "\n", type(df))
# Out:
# Pandas DataFrame:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35    Berlin
# {'Name': ['Alice', 'Bob', 'Charlie'],
#  'Age': [25, 30, 35],
#  'City': ['New York', 'London', 'Berlin']}
# <class 'dict'>
#  <class 'pandas.core.frame.DataFrame'>

# %%
#df.to_csv("output.csv", index=False)

# %%
df_read=pd.read_csv("output.csv")
print("\n Read data from CSV: ")
print(df_read)
display(df_read)
# Out:
#  Read data from CSV:
#       Name  Age      City  Marks
# 0    Alice   25  New York     30
# 1      Bob   30    London     27
# 2  Charlie   35    Berlin     25
# 3   Maulik   18    Jaipur     30
# 4    Sethi   19    Jhansi     18
# 5   Kalkal   19      Pune     20
#       Name  Age      City  Marks
# 0    Alice   25  New York     30
# 1      Bob   30    London     27
# 2  Charlie   35    Berlin     25
# 3   Maulik   18    Jaipur     30
# 4    Sethi   19    Jhansi     18
# 5   Kalkal   19      Pune     20

# %%
df.info()
df.describe()
df.shape
df.columns
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# Name    object
# Age      int64
# City    object
# dtype: object
