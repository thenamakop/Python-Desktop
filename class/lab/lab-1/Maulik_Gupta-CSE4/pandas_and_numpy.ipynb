# %%
import pandas as pd
import numpy as np

# %%
data = [10,20,30,40,50]
series = pd.Series(data)
print("Pandas Series:- ")
print(series)
print(type(series))
# Out:
# Pandas Series:-
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# <class 'pandas.core.series.Series'>
