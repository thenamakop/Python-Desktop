# %% [markdown]
# # Assignment 2

# %% [markdown]
# ## If_else_Statements

# %% [markdown]
# 1. Write the python code that check your roll number is even or odd, and print the weather its even or odd

# %% [markdown]
# 2. Write the python code that check your birth year is a leap year or not

# %% [markdown]
# 3. Write the python code that check your roll number id divisible by which all numbers between 2 to 10(included).

# %% [markdown]
# 4. Write the python code that check the number of vowels in your full name.

# %% [markdown]
# ## For Loop

# %% [markdown]
# 5. Create a dictionay in python using for loop where keys are letters from A-Z and values are the numbers from 1-26, each key value pair corresponds to alpabet-number pair

# %% [markdown]
# 6. Now map each of the letters of you full name from the above dictionary and print the corresponding values, for space print zero

# %% [markdown]
# 7. Find the sum and avarge of your name using values in previous question.

# %% [markdown]
# 8. Find the sum and avarge of your Fathers/Mothers name as done in previous question.

# %% [markdown]
# 9. Create a list of ten of your favourite cities and print their name with their index as shown in class

# %% [markdown]
# ## While Loop

# %% [markdown]
# 10. Write the python code using while loop check weather last four digits of your roll number is a prime number or not

# %% [markdown]
# 11. Write the python code using while loop print the factorial of last two digits of your roll number

# %% [markdown]
# 12. Write the python code for calculating the number of spaces and vowels(A,E,I,O,U) in the paragraph below, you can use string calss and its methods and functions, you can also use loops.
#
#     Anatomically modern humans first arrived on the Indian subcontinent between 73,000 and 55,000 years ago. The earliest known human remains in South Asia date to 30,000 years ago. Sedentariness began in South Asia around 7000 BCE; by 4500 BCE, settled life had spread, and gradually evolved into the Indus Valley Civilisation, one of three early cradles of civilisation in the Old World, which flourished between 2500 BCE and 1900 BCE in present-day Pakistan and north-western India. Early in the second millennium BCE, persistent drought caused the population of the Indus Valley to scatter from large urban centres to villages. Indo-Aryan tribes moved into the Punjab from Central Asia in several waves of migration. The Vedic Period of the Vedic people in northern India (1500–500 BCE) was marked by the composition of their extensive collections of hymns (Vedas). The social structure was loosely stratified via the varna system, incorporated into the highly evolved present-day Jāti system. The pastoral and nomadic Indo-Aryans spread from the Punjab into the Gangetic plain. Around 600 BCE, a new, interregional culture arose; then, small chieftaincies (janapadas) were consolidated into larger states (mahajanapadas). Second urbanization took place, which came with the rise of new ascetic movements and religious concepts, including the rise of Jainism and Buddhism. The latter was synthesized with the preexisting religious cultures of the subcontinent, giving rise to Hinduism.
