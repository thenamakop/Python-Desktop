# %% [markdown]
# # Lab Assignment 1

# %% [markdown]
# ## Variable

# %% [markdown]
# 1. Create a variable and assign your roll number to it

# %%
#For example s=12345

# %% [markdown]
# 2. Create a variable contain special character(@#$%^&) and assign your unique number to it, if it gives error then change it

# %% [markdown]
# 3. Add both variable and show result

# %% [markdown]
# 4. Print the type of variable you declared

# %% [markdown]
# 5. Assign your name to the first variable

# %% [markdown]
# 6. Assign your mothers name to the second variable

# %% [markdown]
# 7. Now again Add both variable using + sign and show result

# %%
# Out:
# 'saurabh kiran'

# %% [markdown]
# 8. Take your birth date(1-31) and birth month as two variable and show its addition, substraction, multiplication, division and mod opertator

# %% [markdown]
# 9. Take two boolean variable(True,False) in your name and other boolean variable as your favourite person and show the "and" "or" and "not" operation on these variable

# %% [markdown]
# ## List

# %% [markdown]
# 10. Create a list of all digits of your roll number

# %% [markdown]
# 11. Append the last two digits of unique id in this list

# %% [markdown]
# 12. Insert your name's first letter on 3rd undex of this list

# %% [markdown]
# 13. Print number using range function, the numbers shound be birth date(0-31) and added 10, ex if your birtdate is 13th feb then till 23 you have to print

# %% [markdown]
# 14. Create a list using above range function and print it

# %% [markdown]
# 15. Print this list in reverse order

# %% [markdown]
# 16. Print every third index of this list from starting till end

# %% [markdown]
# 17. Print the list from fifth index till end using colon

# %% [markdown]
# 18. Print the list from 2nd to 11th index using colon

# %% [markdown]
# 19. Create a list that has your roll number, unquite id , date or birth, name, parents name, your favrite fruit, cusine, and your city name

# %% [markdown]
# 20. Print the first four letters of your parents name from the above list

# %% [markdown]
# ## Tuple

# %% [markdown]
# 21. Create a tuple inserting integers of your roll number

# %% [markdown]
# 22. Insert 20 in this tuple

# %%
#If there is any error in above then rewrite the error here

# %% [markdown]
# 23. Replace third index of this tuple with number 100

# %% [markdown]
# 24. Write the comment in next tab that errors you got while editting and tupe and reason behind them.

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# 25. Create a dictionary and write down roll number, unquite id , date or birth, name, parents name, your favrite fruit, cusine, and your city name as keys and the corresponding answers as values, creating key value pairs.

# %% [markdown]
# 26. Print your city name

# %% [markdown]
# 27. Replace this city name with your dream destination city

# %% [markdown]
# 28. Insert a new key value pair in this dictionary as Unversity: BMU as key:value pair

# %% [markdown]
# 29. Delete your Unique id from this dictionary

# %% [markdown]
# ## Mixed Questions

# %% [markdown]
# 30. Convert a list of ten numbers to a tuple

# %% [markdown]
# 31. Evaluate this expression :
#     2+3-5.5*3+6/2+10%3+6-3.5

# %% [markdown]
# 32. Explain the reason for the output of these bitwise operators
#
#     4 & 5 #Output:4
#
#     4 | 5 #Output:5
#
#     4 ^ 5 #Output:1
#
#     4 >> 2 #Output:1
#
#     4 << 2 #Output:16

# %%
#Show the bitwise result of the above with explanation as comment after each operation

# %% [markdown]
# 32. If Str="Sachin Ramesh Tendulkar" and you are executing Str[a:b] and getting output as 'Ramesh'. What will be the value of a and b here?

# %% [markdown]
# 33. If a string s='Ana De Armas'. Convert this string into a list and print third and fifth index of that list

# %% [markdown]
# 34. Create a dictionary taking first 7 letter and numbers as key:value pairs,
#
#     Example: my_dict = {'a': 1, 'b': 2, 'c': 3}
#
#     Convert this dictionary into list with each index containing each item
#
#     Output: [('a', 1), ('b', 2), ('c', 3)]

# %% [markdown]
# 35. Create a tuple insert every letter your name and your fathers name in that
#
#     Eg: tu=('D','a','k','o','t','a','J','o','h','n','s','o','n','s')
#
#     Convert that tuple to set, print and show the lenth of this set.
