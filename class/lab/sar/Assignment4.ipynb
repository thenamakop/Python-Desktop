# %% [markdown]
# # File Handiling

# %% [markdown]
# Create a txt File with your
#
# 1. name :
# 2. roll no :
# 3. address and :
# 4. pincode :
# 5. phone number :

# %%
fh = open("personal_info.txt", "w")
fh.write("Name: Saraansh Gandhi\nroll_number: 240631\naddress: Room 310, BSH\npincode: 122413\nphone_number = 7982554951")
# Out:
# 106

# %% [markdown]
# 2. Close the above file and display/show if you try to access the above file what will be the result

# %%
fh.close()
fh = open("personal_info.txt", "r")
print(fh.read())
fh.close()
# Out:
# Name: Saraansh Gandhi
# roll_number: 240631
# address: Room 310, BSH
# pincode: 122413
# phone_number = 7982554951

# %% [markdown]
# 3. Open the above file ad append the follwing data in that file

# %% [markdown]
# 4. Read the above file and print the addition of your roll number and pincode

# %% [markdown]
# 5.  Create a csv File with two columns and fist have following data and second have corresponding answers
#
# a. name :
#
# b. roll no :
#
# c. address and :
#
# d. pincode :
#
# e. phone number :

# %% [markdown]
# 6. Read the above file and print the addition of your roll number and phone number

# %%
sorted({5, 2, 1, 3})
# Out:
# [1, 2, 3, 5]

# %%
def func(a, b=[]):
    print(a)
    b.append(a)
    return b

# %%
func(1)
# Out:
# 1
# [1]

# %%
func(2)
# Out:
# 2
# [1, 2]
