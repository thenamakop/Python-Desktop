# %%
display(HTML("""
    <div style='text-align: center; font-size: 40pt; font-weight: bold;'>
        Course Lab File
         <br>
    </div>
"""))

display(HTML("<p style='font-size:22pt;'><b>Course Name: Python Programming</b></p>"))
display(HTML("<p style='font-size:22pt;'><b>Course Code: CSE2025</b></p>"))
display(HTML("<p style='font-size:22pt;'><b>Section: CSE-1</b></p>"))
display(HTML("<p style='font-size:22pt;'><b>Student Name: Kiran Sharma</b></p>"))
display(HTML("<p style='font-size:22pt;'><b>Roll No: 123</b></p>"))
display(HTML("<p style='font-size:22pt;'><b>Date: April 27, 2025</b></p>"))
display(HTML("<p style='font-size:22pt;'><b>Instructor Name: Dr. Kiran Sharma</b></p>"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 display(HTML("""
#       2     <div style='text-align: center; font-size: 40pt; font-weight: bold;'>
#       3         Course Lab File
#       4          <br>
#       5     </div>
#       6 """))
#       8 display(HTML("<p style='font-size:22pt;'><b>Course Name: Python Programming</b></p>"))
#       9 display(HTML("<p style='font-size:22pt;'><b>Course Code: CSE2025</b></p>"))
#
# NameError: name 'HTML' is not defined

# %% [markdown]
# # **Lab Procedures**

# %% [markdown]
# # **1. Implementation of datatypes, operators, and input/output**

# %% [markdown]
# ## 1a). Data Types

# %% [markdown]
# ## 1b). Operators

# %% [markdown]
# ## 1c). Input/Output

# %% [markdown]
# # **2. Implementation of strings, list, and tuples, sets and dictionary**

# %% [markdown]
# ## 2a). Strings

# %% [markdown]
# ## 2b). List

# %% [markdown]
# # **3. Implementation of conditional statements and loops**

# %% [markdown]
# ## 5. Implementation of functions and modules

# %% [markdown]
# ## 6. Data collection and file handling

# %% [markdown]
# ## 7. Implementation of pandas and matplotlib

# %% [markdown]
# ## 8. Implementation of NumPy and seaborn

# %% [markdown]
# ## 9. Implementation of Exception handling

# %% [markdown]
# ## 10. Data analysis of real-world problem
