# %%
from IPython.display import HTML
display(HTML("""
    <div style='text-align: center; font-size: 40pt; font-weight: bold;'>
        <div>Python Lab Evaluation-II</div>
        <div>Marks: 20</div>
        <div>SET-2</div>
    </div>
"""))
display(HTML("<p style='font-size:22pt;'><b>Course Name: Python Programming</b></p>"))
display(HTML("<p style='font-size:22pt;'><b>Course Code: CSE2025</b></p>"))
display(HTML("<p style='font-size:22pt;'><b>Section: CSE-1</b></p>"))
display(HTML("<p style='font-size:22pt;'><b>Student Name: ..............</b></p>"))
display(HTML("<p style='font-size:22pt;'><b>Roll No: ..............</b></p>"))
display(HTML("<p style='font-size:22pt;'><b>Date: April 30, 2025</b></p>"))
display(HTML("<p style='font-size:22pt;'><b>PC No.: ........</b></p>"))
display(HTML("<p style='font-size:22pt;'><b>Instructor Name: Dr. Kiran Sharma</b></p>"))
# Out:
#     <div style='text-align: center; font-size: 40pt; font-weight: bold;'>
#         <div>Python Lab Evaluation-II</div>
#         <div>Marks: 20</div>
#         <div>SET-2</div>
#     </div>
# <p style='font-size:22pt;'><b>Course Name: Python Programming</b></p>
# <p style='font-size:22pt;'><b>Course Code: CSE2025</b></p>
# <p style='font-size:22pt;'><b>Section: CSE-1</b></p>
# <p style='font-size:22pt;'><b>Student Name: ..............</b></p>
# <p style='font-size:22pt;'><b>Roll No: ..............</b></p>
# <p style='font-size:22pt;'><b>Date: April 30, 2025</b></p>
# <p style='font-size:22pt;'><b>PC No.: ........</b></p>
# <p style='font-size:22pt;'><b>Instructor Name: Dr. Kiran Sharma</b></p>

# %%
display(HTML("<p style='font-size:22pt;'><b>Instructions</b></p>"))
# Out:
# <p style='font-size:22pt;'><b>Instructions</b></p>

# %% [markdown]
# * Cell Phone not allowed. If found, you will be marked 0.
# * Notes and any sheets exchange is not allowed. If found, you will be marked 0.
# * Kindly sit at your signed seat and fill all your credentials in sheet.
# * All questions are compulsory and should be performed in this sheet only. You may add any number of coding cells as you required.
# * Save sheet with your Name_RollNo(last 4 digits)_Section. Eg: "Kiran_1234_CSE1".
# * If you don't save your sheet and lost later on, we are not resposnsible.
# * No makeup is allowed. This is the final evaluation.
# * Note: You are under CCTV suveliance.

# %% [markdown]
# # Data Description: Netflix Movies and TV Shows Dataset
#
# **Column Descriptions:**
#
# * **show_id:** Unique identifier for each Netflix title.
# * **type:** Indicates whether the content is a Movie or a TV Show.
# * **title:** Name of the movie or TV show.
# * **director:** Name of the director(s). Some values are missing.
# * **cast:** List of actors/actresses in the content. Some values are missing.
# * **country:** The country where the movie/TV show was produced.
# * **date_added:** The date when the content was added to Netflix.
# * **release_year:** The year when the content was originally released.
# *  **rating:** Content rating (e.g., TV-MA, TV-14, PG-13).
# * **duration:**
# * * For Movies: Duration is given in minutes.
# * * For TV Shows: Number of seasons is provided.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Read The csv file "*netflix_titles.csv*" and display the information of the file. [1 Mark]

# %% [markdown]
# # 2. Identify and display the average Release Year of each Type. [2 Marks]

# %% [markdown]
# # 3.Create a subset of data based on the given condition: Movies released after 2015 in the United States.     [2 Marks]

# %% [markdown]
# # 4. (a) Plot a bar chart to to display Number of Titles per Rating in subset data. [2 Marks]
#
# #(b)Visualize the results in a bar chart.   [2 marks]
#
# # (c) Save figure as png. [1 Marks]

# %% [markdown]
# # 5. Create a module named "date_added.py" that extracts the month and year from the date_added column and  adds them as new columns added_month and added_month in subset data. [5 Marks]
#
# Note: As we are passing dataframe to function inside module. So import Pandas inside module
#
# # (b) Import the module and display the data with columns 'title', 'date_added', 'added_month', 'added_year'.   [2 Marks]
#
#
# # (c) Write the output back in csv file name as "Updated_data.csv". [1 Marks]
#
# # (d) Display the number of Titles Added Per Montha and Year. Displat top 10. [2 Marks]
